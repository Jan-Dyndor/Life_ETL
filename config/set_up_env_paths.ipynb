# %%
import sys, os 
from pathlib import Path

# %%
repo_root = Path(os.getcwd()).parent
# Out:
# d:\Life_ETL_folder\Life_ETL

# %%
if str(repo_root) not in sys.path:
    sys.path.append(str(repo_root))
