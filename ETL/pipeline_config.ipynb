# %%
# %run ../config/set_up_env_paths

# %%
from config.core import config

# %%
table_configs = [
    {
        "table": config.nbp.table_a,
        "rate_type": config.nbp.rate_type_a,
        "update_frequency": config.nbp.update_frequency_a,
    },
    {
        "table": config.nbp.table_b,
        "rate_type": config.nbp.rate_type_b,
        "update_frequency": config.nbp.update_frequency_b,
    },
]

dbutils.jobs.taskValues.set("inputs", table_configs)
