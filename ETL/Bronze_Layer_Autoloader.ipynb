# %%
# %run ../config/set_up_env_paths

# %%
from config.core import config

table_name = dbutils.widgets.get("table") # loop inside Databricks Pipeline

# %%
# Read Table

df = spark.table(
    f"{config.catalog.catalog_name}.{config.catalog.source_schema}.{table_name}"
)

# Save Table in bronze layer
df.write.format("delta").mode("overwrite").saveAsTable(f"{config.catalog.catalog_name}.{config.catalog.bronze_schema}.{table_name}")
