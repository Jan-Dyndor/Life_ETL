# %%
table_name = dbutils.widgets.get("table")

# %%
# Read Table

df = spark.table(f"nbp.source.{table_name}")

# Save Table in bronze layer
df.write.format("delta").mode("overwrite").saveAsTable(f"nbp.bronze.{table_name}")
